# %%
import cv2 as cv
import numpy as np

# %%
#image show
img = cv.imread('test0.jpeg')
cv.imshow('image',img)
cv.waitKey(0)

# %%
#webcam/videos
webcam = cv.VideoCapture(0)
webcam.set(3, 640) #width
webcam.set(4, 480) #length
webcam.set(10, 100) #brightness
while True:
    success, img = webcam.read()
    cv.imshow("Video" , img)
    if cv.waitKey(1) &0xFF == ord('q'):
        break

# %%
#basic functions
import cv2 as cv
import numpy as np

img = cv.imread('test0.jpeg')
kernel = np.ones((5,5), np.uint8)

imgGray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
imgBlur = cv.GaussianBlur(img, (7,7), 0)
imgCanny = cv.Canny(imgGray, 100, 100)
imgDialation = cv.dilate(imgCanny, kernel, iterations=1)

cv.imshow("Gray", imgGray)
cv.imshow("Blur", imgBlur)
cv.imshow("Canny", imgCanny)
cv.imshow("Dilate", imgDialation)

cv.waitKey(0)

# %%
#crop and resize
import cv2 as cv
import numpy as np

img = cv.imread('test0.jpeg')
print(img.shape)
imgResize = cv.resize(img, (300,200))
imgCropped = img[0:200,100:250]
cv.imshow("img", img)
cv.imshow("img resized", imgResize)
cv.imshow("cropped", imgCropped)
cv.waitKey(0)
# Out:
# (281, 180, 3)

# %%
#text and lines and shapes on the img
import cv2 as cv
import numpy as np

img = np.zeros((512,512,3))
#img[:] = 255,0,0
#img[100:200, 300:500] = 25,0,0
cv.line(img, (0,0), (img.shape[1], img.shape[0]), (0,255,0), 3) #the last parameter is thickness
cv.rectangle(img, (0,0), (250,400), (0,0,200), 2)
#cv.rectangle(img, (0,0), (250,400), (0,0,200), cv.FILLED)
cv.circle(img, (69, 69), 47, (0,255,255), 2) #centre, radius
cv.putText(img, "your mom", (20, 50), cv.FONT_HERSHEY_COMPLEX, 1, (100, 170, 0), 1) #scale, color, thickness
cv.imshow("img", img)

cv.waitKey(0)

# %%
# Get a part of the image between 4 points - like a card or a square or a rectangular object
import cv2 as cv
import numpy as np
width, height = 107, 205 #just the dimensions of the chosen part of the image. more width will make it look stretched
img = cv.imread('test0.jpeg')
pts1 = np.float32([[10,45],[67,45],[10,250],[67,250]])
pts2 = np.float32([[0,0],[width,0],[0,height],[width,height]])
matrix = cv.getPerspectiveTransform(pts1, pts2)
imgOutput = cv.warpPerspective(img, matrix, (width, height))
cv.imshow("img", imgOutput)

cv.waitKey(0)

# %%
#images in rows and columns
import cv2 as cv
import numpy as np

img = cv.imread('test0.jpeg')

def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range ( 0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv.cvtColor( imgArray[x][y], cv.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv.cvtColor(imgArray[x], cv.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver

imgGray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
 
imgStack = stackImages(0.5,([img,imgGray,img],[img,img,img]))
#hor = np.hstack((img, img))
#ver = np.vstack((hor, hor))
#cv.imshow("himg", hor)
#cv.imshow("vimg", ver)
cv.imshow("ImageStack",imgStack)
cv.waitKey(0)

# %%
#extract red out of spidey with creatng trackbar stuff/ color detection
import cv2 as cv
import numpy as np
def empty(a):
    pass
cv.namedWindow("TrackBars")
cv.resizeWindow("TrackBars", 640, 240)
cv.createTrackbar("Hue min", "TrackBars", 0, 179, empty)
cv.createTrackbar("Hue max", "TrackBars", 18, 179, empty)
cv.createTrackbar("Sat min", "TrackBars", 129, 255, empty)
cv.createTrackbar("Sat max", "TrackBars", 255, 255, empty)
cv.createTrackbar("Val min", "TrackBars", 0, 255, empty)
cv.createTrackbar("Val max", "TrackBars", 255, 255, empty)
def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range ( 0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv.cvtColor( imgArray[x][y], cv.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv.cvtColor(imgArray[x], cv.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver
while True:
    img = cv.imread('test0.jpeg')
    imgHSV = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    h_min = cv.getTrackbarPos("Hue min", "TrackBars")
    h_max = cv.getTrackbarPos("Hue max", "TrackBars")
    s_min = cv.getTrackbarPos("Sat min", "TrackBars")
    s_max = cv.getTrackbarPos("Sat max", "TrackBars")
    v_min = cv.getTrackbarPos("Val min", "TrackBars")
    v_max = cv.getTrackbarPos("Val max", "TrackBars")
    
    lower = np.array([h_min, s_min, v_min])
    upper = np.array([h_max, s_max, v_max])
    mask = cv.inRange(imgHSV, lower, upper)
    imgResult = cv.bitwise_and(img, img, mask=mask)
    #cv.imshow("img", img)
    #cv.imshow("HSV image", imgHSV)
    #cv.imshow("mask", mask)
    #cv.imshow("Result", imgResult)
    imgStack = stackImages(1.6, ([img, imgHSV], [mask, imgResult]))
    cv.imshow("stacked images", imgStack)
    cv.waitKey(1)

# %%
#finding and naming shapes
import cv2 as cv
import numpy as np

img = cv.imread('shape.png')
imgGray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
imgBlur = cv.GaussianBlur(imgGray, (7,7), 1)
imgCanny = cv.Canny(imgBlur, 100, 100)


def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range ( 0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv.cvtColor( imgArray[x][y], cv.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv.cvtColor(imgArray[x], cv.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver

def getContours(img):
    contours, hierarchy = cv.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
    for cnt in contours:
        area = cv.contourArea(cnt)
        if area>500:
            cv.drawContours(imgContour, cnt, -1, (255, 0 ,0), 3)
            perimeter = cv.arcLength(cnt, True)
            approx = cv.approxPolyDP(cnt, 0.02*perimeter, True)
            #print(len(approx))
            objcor = len(approx)
            x, y, w, h = cv.boundingRect(approx)
            if objcor==3:
                objectType="Tri"
            elif objcor==4:
                aspRatio = w/float(h)
                if aspRatio>0.95 and aspRatio<1.05:
                    objectType="Square"
                else:
                    objectType = "Rectangle"
            elif objcor>4: objectType = "Circle"
            else:
                objectType="None"
            cv.rectangle(imgContour, (x,y),(x+w,y+h), (0,255,0), 2)
            cv.putText(imgContour,objectType, (x+(w//2)-10, y+(h//2)+10), cv.FONT_HERSHEY_COMPLEX, 0.5, (0,0,0), 2)
            
imgContour = img.copy()
imgBlank = np.zeros_like(img)
getContours(imgCanny)
imgStack = stackImages(1, ([img, imgGray, imgBlur], [imgCanny, imgContour, imgBlank]))

cv.imshow("stacked images", imgStack)
cv.waitKey(0)

# %%
#recognize faces in images
import cv2 as cv
import numpy as np

faceCascade = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_default.xml")
img = cv.imread('face.png')
imgGray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(imgGray, 1.1, 4)

for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w, y+h), (255,0,0), 2)
cv.imshow("Result", img)
cv.waitKey(0)

# %%
#recognize faces on webcam
import cv2 as cv
import numpy as np

faceCascade = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_default.xml")

webcam = cv.VideoCapture(0)
webcam.set(3, 640) #width
webcam.set(4, 480) #length
webcam.set(10, 100) #brightness
while True:
    success, img = webcam.read()
    faces = faceCascade.detectMultiScale(img, 1.1, 4)
    for (x,y,w,h) in faces:
        cv.rectangle(img,(x,y),(x+w, y+h), (255,0,0), 2)
        cv.putText(img, "FOUND YOU!!", (20, 50), cv.FONT_HERSHEY_COMPLEX, 1, (100, 0), 3)
    cv.imshow("Video" , img)
    if cv.waitKey(1) &0xFF == ord('q'):
        break
cv.destroyAllWindows()

# %%
#color detection using webcam so that we can get the hue, sat and val of different colors
import cv2 as cv
import numpy as np

def empty(a):
    pass

def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range (0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv.cvtColor( imgArray[x][y], cv.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv.cvtColor(imgArray[x], cv.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver

cv.namedWindow("TrackBars")
cv.resizeWindow("TrackBars", 640, 240)
cv.createTrackbar("Hue min", "TrackBars", 0, 179, empty)
cv.createTrackbar("Hue max", "TrackBars", 18, 179, empty)
cv.createTrackbar("Sat min", "TrackBars", 129, 255, empty)
cv.createTrackbar("Sat max", "TrackBars", 255, 255, empty)
cv.createTrackbar("Val min", "TrackBars", 0, 255, empty)
cv.createTrackbar("Val max", "TrackBars", 255, 255, empty)

webcam = cv.VideoCapture(0)
webcam.set(3, 640) #width
webcam.set(4, 480) #length
webcam.set(10, 160) #brightness
while True:
    success, img = webcam.read()
    imgHSV = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    h_min = cv.getTrackbarPos("Hue min", "TrackBars")
    h_max = cv.getTrackbarPos("Hue max", "TrackBars")
    s_min = cv.getTrackbarPos("Sat min", "TrackBars")
    s_max = cv.getTrackbarPos("Sat max", "TrackBars")
    v_min = cv.getTrackbarPos("Val min", "TrackBars")
    v_max = cv.getTrackbarPos("Val max", "TrackBars")
    
    lower = np.array([h_min, s_min, v_min])
    upper = np.array([h_max, s_max, v_max])
    mask = cv.inRange(imgHSV, lower, upper)
    imgResult = cv.bitwise_and(img, img, mask=mask)
    imgStack = stackImages(1, ([img,mask, imgResult]))
    cv.imshow("Video" , imgStack)
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# %%
#Paint
import cv2 as cv
import numpy as np

webcam = cv.VideoCapture(0)
webcam.set(3, 640) #width
webcam.set(4, 480) #length
webcam.set(10, 160) #brightness

mycolors = [[133,56,0,159,156,255],
            [57,76,0,100,255,255],
            [90,48,0,118,255,255]]
mycolorpaints = [[255,0,255],
                 [0,255,0],
                 [255,0,0]]


def findColor(img, mycolors, mycolorpaints):
    
    imgHSV = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    colorCount = 0 
    newPoints = []
    for color in mycolors:
        lower = np.array(color[0:3])
        upper = np.array(color[3:6])
        mask = cv.inRange(imgHSV, lower, upper)
        x,y = getContours(mask)
        cv.circle(imgFinal, (x,y), 10, mycolorpaints[colorCount], cv.FILLED)
        if x!=0 and y!=0:
            newPoints.append([x,y,colorCount])
        colorCount+=1
    return newPoints
        
def getContours(img):
    contours, hierarchy = cv.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
    x,y,w,h = 0,0,0,0
    for cnt in contours:
        area = cv.contourArea(cnt)
        if area>500:
            #cv.drawContours(imgFinal, cnt, -1, (255, 0 ,0), 1)
            perimeter = cv.arcLength(cnt, True)
            approx = cv.approxPolyDP(cnt, 0.02*perimeter, True)
            #print(len(approx))
            x, y, w, h = cv.boundingRect(approx)
    return x+w//2, y

def drawcolor(mypoints, mycolorpaints):
    for point in mypoints:
        cv.circle(imgFinal, (point[0],point[1]), 10, mycolorpaints[point[2]], cv.FILLED)

mypoints = []
while True:
    success, img = webcam.read()
    imgFinal = img.copy()
    newPoints = findColor(img, mycolors, mycolorpaints)
    if len(newPoints)!=0:
        for new in newPoints:
            mypoints.append(new)
            
    if len(mypoints)!=0:
        drawcolor(mypoints, mycolorpaints)

    cv.imshow("Video" , imgFinal)

    if cv.waitKey(1) &0xFF == ord('q'):
        break

# %%
import cv2 as cv
import numpy as np
from collections import deque

green = np.array([34,52,147,103,255,255])
kernel = np.ones((5, 5), np.uint8)
bluep = []
redp = []
yellowp = []

#define colours
mycolours = [[0,0,255],[0,255,255],[255,0,0]]
"""
paintscreen = np.ones((530,640,3))
paintscreen = cv.rectangle(paintscreen, (50,10), (170, 55), (0,0,0), 2)
paintscreen = cv.rectangle(paintscreen, (190,10), (310, 55), mycolours[2], -1)
paintscreen = cv.rectangle(paintscreen, (330,10), (450, 55), mycolours[1], -1)
paintscreen = cv.rectangle(paintscreen, (470,10), (590, 55), mycolours[0], -1)

cv.putText(paintscreen, "Erase ALL", (55, 30), cv.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1) #scale, color, thickness
cv.putText(paintscreen, "Blue", (195, 30), cv.FONT_HERSHEY_COMPLEX, 1, (0, 250, 0), 1) #scale, color, thickness
cv.putText(paintscreen, "Green", (335, 30), cv.FONT_HERSHEY_COMPLEX, 1, (0, 0, 250), 1) #scale, color, thickness
cv.putText(paintscreen, "Red", (475, 30), cv.FONT_HERSHEY_COMPLEX, 1, (250, 0, 0), 1) #scale, color, thickness

cv.namedWindow('My Paint', cv.WINDOW_AUTOSIZE)
"""


webcam = cv.VideoCapture(0)
webcam.set(3, 640) #width
webcam.set(4, 480) #length
webcam.set(10, 100) #brightness
#cv.imshow("My Paint", paintscreen)

def getContours(img):
    contours, hierarchy = cv.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
    x,y,w,h = 0,0,0,0
    for cnt in contours:
        area = cv.contourArea(cnt)
        if area>500:
            #cv.drawContours(imgFinal, cnt, -1, (255, 0 ,0), 1)
            perimeter = cv.arcLength(cnt, True)
            approx = cv.approxPolyDP(cnt, 0.02*perimeter, True)
            #print(len(approx))
            x, y, w, h = cv.boundingRect(approx)
    return x+w//2, y

""""def findColor(img, mycolors):
    
    for color in mycolors:
        lower = np.array(color[0:3])
        upper = np.array(color[3:6])
        mask = cv.inRange(imgHSV, lower, upper)
        x,y = getContours(mask)
        cv.circle(imgFinal, (x,y), 10, mycolorpaints[colorCount], cv.FILLED)
        if x!=0 and y!=0:
            if y>10 and y<55:
                if x>190 and x<310:
                    blue_p.append(x,y)
                if x>470 and x<590:
                    red_p.append(x,y)
                if x>330 and x<450:
                    green_p.append(x,y)
    return newPoints
"""

while True:
    (grabbed, img) = webcam.read()
    img = cv.rectangle(img, (50,10), (170, 55), (122,122,122), -1)
    img = cv.rectangle(img, (190,10), (310, 55), mycolours[2], -1)
    img = cv.rectangle(img, (330,10), (450, 55), mycolours[1], -1)
    img = cv.rectangle(img, (470,10), (590, 55), mycolours[0], -1)

    cv.putText(img, "Erase ALL", (55, 30), cv.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1) #scale, color, thickness
    cv.putText(img, "Blue", (195, 30), cv.FONT_HERSHEY_COMPLEX, 1, (0, 250, 0), 1) #scale, color, thickness
    cv.putText(img, "yellow", (335, 30), cv.FONT_HERSHEY_COMPLEX, 1, (0, 0, 250), 1) #scale, color, thickness
    cv.putText(img, "Red", (475, 30), cv.FONT_HERSHEY_COMPLEX, 1, (250, 0, 0), 1) #scale, color, thickness
    
    imgHSV = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    greenHSV = cv.inRange(imgHSV, green[0:3], green[3:6])
    greenHSV = cv.erode(greenHSV, kernel, iterations=1)
    greenHSV = cv.morphologyEx(greenHSV, cv.MORPH_OPEN, kernel)
    greenHSV = cv.dilate(greenHSV, kernel, iterations=1)
    x,y = getContours(greenHSV)
    #print (x,y)
    points = []
    points.append([x,y])
    colourIndex=0
    if x!=0 and y!=0:
        if 10 < y < 55:
            if 190 < x < 310:
                colourIndex=0 #redp.append(points[p])
            elif 330 < x < 450:
                colourIndex=1 #yellowp.append(points[p])
            elif 470 < x < 590:
                colourIndex=2 #bluep.append(points[p])
        else:
            if colourIndex == 0:
                redp.append([x,y])
            elif colourIndex == 1:
                yellowp.append([x,y])
            elif colourIndex == 2:
                bluep.append([x,y])
         
    finalpoints = [redp, yellowp, bluep]  #[[(),()],[(),()]]
    #imgFinal = img.copy()
    for i in range(len(finalpoints)):
        for j in range(1, len(finalpoints[i])):
        #for k in range(1, len(finalpoints[i])):
            cv.line(img, (finalpoints[i][j-1][0],finalpoints[i][j-1][1]), (finalpoints[i][j][0], finalpoints[i][j][1]), mycolours[i], 2)
                #cv.line(paintWindow, points[i][j][k - 1], points[i][j][k], colors[i], 2)
    cv.imshow("Video" , img)
    if cv.waitKey(1) &0xFF == ord('q'):
        break
